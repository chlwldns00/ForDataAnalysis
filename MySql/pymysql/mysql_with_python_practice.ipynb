# %% [markdown]
# ### 파이썬 크롤링
# > 데이터를 자동으로 저장하는 모습을 보여드리기 위해, 크롤링 기술을 가볍게 활용하기로 함 <br>
# > 파이썬 입문과 크롤링 부트캠프에서 익힌 크롤링 기술을 활용하기로 함

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.card-body')
    for item in data:
        category = item.select_one('h2.card-title').get_text().replace('관련 상품 추천', '').strip()
        product = item.select_one('h4.card-text').get_text().replace('상품명:', '').strip()
        print (category, product)
# Out:
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 여름이불세트 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 매트리스커버 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 매트리스커버 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 매트리스커버 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 차콜
# 행거도어 WEMAX 다용도 문옷걸이, 화이트, 1개
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 매트리스커버 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 화이트
# 매트리스커버 프랑떼 항균 방수 매트리스커버, 화이트
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 화이트
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# 여름이불세트 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
# 여름이불세트 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
# 여름이불세트 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
# 여름이불세트 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이
# 여름이불세트 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이
# 여름이불세트 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이
# 행거도어 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
# 행거도어 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
# 행거도어 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
# 행거도어 [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
# 행거도어 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
# 행거도어 숲속애 웨이브 도어후크 5구, 블랙, 1개
# 행거도어 펀타스틱 다용도 문틀걸이, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 4구, 화이트, 1개
# 행거도어 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
# 행거도어 까사마루 블랑 접이식 문걸이 건조대, 1개
# 행거도어 선우랜드 우드볼 도어훅 6구, 실버, 1개
# 행거도어 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 10구, 화이트, 1개
# 행거도어 코멧 홈 우드볼 도어행거, 6구, 혼합색상
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 행거도어 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
# 행거도어 스파이더락 도어후크 8구, 화이트, 1개
# 행거도어 선우랜드 우드볼 도어훅 6구, 화이트, 1개
# 행거도어 코멧 홈 우드볼 도어행거, 10구, 혼합색상
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키핑크
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 매트리스커버 프로텍트어베드 베이직 매트리스 방수커버, 그레이

# %% [markdown]
# ### Schema 구성
# > workbench 를 통해, schema 구성 <br>
# > 일회성 schema 는 파이썬으로 자동으로 하기보다는 workbench 를 활용하는 것이 일반적임
#
# ```sql
# DROP DATABASE IF EXISTS ecommerce;
# CREATE DATABASE ecommerce;
# USE ecommerce;
# CREATE TABLE teddyproducts (
#     ID INT UNSIGNED NOT NULL AUTO_INCREMENT,
#     TITLE VARCHAR(200) NOT NULL,
#     CATEGORY VARCHAR(20) NOT NULL,
#     PRIMARY KEY(ID)
# );
# ```

# %% [markdown]
# ### 크롤링 + mysql 저장

# %%
import requests
from bs4 import BeautifulSoup
import pymysql

db = pymysql.connect(
    host='localhost', 
    port=3306, 
    user='funcoding', 
    passwd='funcoding', 
    db='ecommerce', 
    charset='utf8')
cursor = db.cursor()

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    soup = BeautifulSoup(res.content, 'html.parser')
    data = soup.select('div.card-body')
    for item in data:
        category = item.select_one('h2.card-title').get_text().replace('관련 상품 추천', '').strip()
        product = item.select_one('h4.card-text').get_text().replace('상품명:', '').strip()
        print (category, product)
        SQL = """INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('""" + product + """', '""" + category + """');"""
        print(SQL)
        cursor.execute(SQL)        

db.commit()
db.close()
# Out:
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루', '매트리스커버');
# 여름이불세트 슈에뜨룸 선인장 리플 침구 세트, 베이지
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('슈에뜨룸 선인장 리플 침구 세트, 베이지', '여름이불세트');
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조', '행거도어');
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보드래 헬로우 누빔 매트리스커버, 핑크', '매트리스커버');
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 차콜
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보드래 퍼펙트 누빔 매트리스커버, 차콜', '매트리스커버');
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('피아블 클래식 방수 매트리스커버, 화이트', '매트리스커버');
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이', '매트리스커버');
# 매트리스커버 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이', '매트리스커버');
# 매트리스커버 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이', '매트리스커버');
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이', '매트리스커버');
# 매트리스커버 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리', '매트리스커버');
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 차콜
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('바숨 순면 누빔 침대 매트리스커버, 차콜', '매트리스커버');
# 행거도어 WEMAX 다용도 문옷걸이, 화이트, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('WEMAX 다용도 문옷걸이, 화이트, 1개', '행거도어');
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑', '매트리스커버');
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보몽드 순면스퀘어 누빔매트커버, 다크그레이', '매트리스커버');
# 매트리스커버 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보드래 국내산 순면 60수 누빔 매트리스커버, 그레이', '매트리스커버');
# 매트리스커버 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보드래 퍼펙트 누빔 매트리스커버, 베이지핑크', '매트리스커버');
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜', '매트리스커버');
# 매트리스커버 바숨 순면 누빔 침대 매트리스커버, 화이트
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('바숨 순면 누빔 침대 매트리스커버, 화이트', '매트리스커버');
# 매트리스커버 프랑떼 항균 방수 매트리스커버, 화이트
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('프랑떼 항균 방수 매트리스커버, 화이트', '매트리스커버');
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루', '매트리스커버');
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이', '매트리스커버');
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지', '매트리스커버');
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독', '매트리스커버');
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('더자리 에코항균 마이크로 매트리스커버, 밀키그레이', '매트리스커버');
# 매트리스커버 보몽드 순면스퀘어 누빔매트커버, 화이트
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보몽드 순면스퀘어 누빔매트커버, 화이트', '매트리스커버');
# 매트리스커버 피아블 클래식 방수 매트리스커버, 화이트
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('피아블 클래식 방수 매트리스커버, 화이트', '매트리스커버');
# 매트리스커버 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이', '매트리스커버');
# 여름이불세트 쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('쉬즈홈 모던그리드 순면 여름이불 베개커버 패드세트, 핑크', '여름이불세트');
# 여름이불세트 스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('스코홈 빅리플 여름 차렵이불패드 3종 세트, 마린그레이', '여름이불세트');
# 여름이불세트 아망떼 시어서커 리플 홑이불 패드세트, 웨이크
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('아망떼 시어서커 리플 홑이불 패드세트, 웨이크', '여름이불세트');
# 여름이불세트 마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('마이센스 무더운 여름엔 시어서커 여름이불 패드 베개 이불세트 30종, 시어서커_파스텔그레이', '여름이불세트');
# 여름이불세트 믹스앤매치 로라 프릴 시어서커 침구세트, 그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('믹스앤매치 로라 프릴 시어서커 침구세트, 그레이', '여름이불세트');
# 여름이불세트 에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('에피소드1 샤베트 프릴 시어서커 여름이불패드세트, 그레이', '여름이불세트');
# 여름이불세트 슈에뜨룸 선인장 리플 침구 세트, 베이지
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('슈에뜨룸 선인장 리플 침구 세트, 베이지', '여름이불세트');
# 여름이불세트 아망떼 시어서커 리플 홑이불 패드세트, 허브티
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('아망떼 시어서커 리플 홑이불 패드세트, 허브티', '여름이불세트');
# 여름이불세트 지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('지베딩 아이스베어 시어서커 여름침구 풀세트, 민트그레이', '여름이불세트');
# 여름이불세트 쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('쁘리엘르 테스 시어서커 여름이불 패드세트, 그레이', '여름이불세트');
# 여름이불세트 쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('쉬즈홈 시어서커 홑이불 + 토퍼 + 베개커버 세트, 나나 옐로우', '여름이불세트');
# 여름이불세트 아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('아망떼 시어서커 리플 퀼팅 이불패드세트, 리엔나', '여름이불세트');
# 여름이불세트 바자르 트로피컬 인견 여름 이불세트 인견이불 + 베개커버 2p + 인견패드, 그린
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('선우랜드 우드볼 도어훅 4구, 실버, 1개', '행거도어');
# 행거도어 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개', '행거도어');
# 행거도어 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트', '행거도어');
# 행거도어 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개', '행거도어');
# 행거도어 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개', '행거도어');
# 행거도어 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개', '행거도어');
# 행거도어 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트', '행거도어');
# 행거도어 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개', '행거도어');
# 행거도어 선우랜드 우드볼 도어훅 10구, 실버, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('선우랜드 우드볼 도어훅 10구, 실버, 1개', '행거도어');
# 행거도어 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개', '행거도어');
# 행거도어 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1', '행거도어');
# 행거도어 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('코시나 무타공 문걸이 후크선반 1단, 화이트, 1개', '행거도어');
# 행거도어 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개', '행거도어');
# 행거도어 [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('[아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량', '행거도어');
# 행거도어 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개', '행거도어');
# 행거도어 숲속애 웨이브 도어후크 5구, 블랙, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('숲속애 웨이브 도어후크 5구, 블랙, 1개', '행거도어');
# 행거도어 펀타스틱 다용도 문틀걸이, 화이트, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('펀타스틱 다용도 문틀걸이, 화이트, 1개', '행거도어');
# 행거도어 선우랜드 우드볼 도어훅 4구, 화이트, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('선우랜드 우드볼 도어훅 4구, 화이트, 1개', '행거도어');
# 행거도어 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개', '행거도어');
# 행거도어 까사마루 블랑 접이식 문걸이 건조대, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('까사마루 블랑 접이식 문걸이 건조대, 1개', '행거도어');
# 행거도어 선우랜드 우드볼 도어훅 6구, 실버, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('선우랜드 우드볼 도어훅 6구, 실버, 1개', '행거도어');
# 행거도어 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개', '행거도어');
# 행거도어 선우랜드 우드볼 도어훅 10구, 화이트, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('선우랜드 우드볼 도어훅 10구, 화이트, 1개', '행거도어');
# 행거도어 코멧 홈 우드볼 도어행거, 6구, 혼합색상
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('코멧 홈 우드볼 도어행거, 6구, 혼합색상', '행거도어');
# 행거도어 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조', '행거도어');
# 행거도어 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('코시나 무타공 문걸이 후크선반 2단, 화이트, 1개', '행거도어');
# 행거도어 스파이더락 도어후크 8구, 화이트, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('스파이더락 도어후크 8구, 화이트, 1개', '행거도어');
# 행거도어 선우랜드 우드볼 도어훅 6구, 화이트, 1개
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('선우랜드 우드볼 도어훅 6구, 화이트, 1개', '행거도어');
# 행거도어 코멧 홈 우드볼 도어행거, 10구, 혼합색상
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('코멧 홈 우드볼 도어행거, 10구, 혼합색상', '행거도어');
# 매트리스커버 보드래 헬로우 누빔 매트리스커버, 핑크
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보드래 헬로우 누빔 매트리스커버, 핑크', '매트리스커버');
# 매트리스커버 보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('보몽드 순면스퀘어 솔리드 누빔매트커버, 아이보리', '매트리스커버');
# 매트리스커버 더자리 에코항균 마이크로 매트리스커버, 밀키핑크
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('더자리 에코항균 마이크로 매트리스커버, 밀키핑크', '매트리스커버');
# 매트리스커버 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 미스밍고', '매트리스커버');
# 매트리스커버 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이', '매트리스커버');
# 매트리스커버 프로텍트어베드 베이직 매트리스 방수커버, 그레이
# INSERT INTO teddyproducts (TITLE, CATEGORY) VALUES('프로텍트어베드 베이직 매트리스 방수커버, 그레이', '매트리스커버');

# %% [markdown]
# ### mysql 데이터 읽기

# %%
# 1. 라이브러리 가져오기
import pymysql

# 2. 접속하기
db = pymysql.connect(
    host='localhost', 
    port=3306, 
    user='funcoding', 
    passwd='funcoding', 
    db='ecommerce', 
    charset='utf8')

# 3. 커서 가져오기
cursor = db.cursor()
SQL = "SELECT * FROM teddyproducts WHERE CATEGORY = '행거도어';"
cursor.execute(SQL)
rows = cursor.fetchall()
for row in rows:
    print (row[1])

# 7. DB 연결 닫기
db.close()
# Out:
# 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# WEMAX 다용도 문옷걸이, 화이트, 1개
# 이코디 5단 엔틱 도어 행거, 브라운, 1개
# 선우랜드 우드볼 도어훅 4구, 실버, 1개
# 리은상점 다용도 도어훅 문걸이 행거 모자걸이 머플러 목도리 걸이, 화이트, 5개
# 퍼니스코 다용도걸이 모자걸이 가방걸이 도어훅 도어행거 문걸이, 엔틱브라운, 1세트
# 스텐 도어후크 옷걸이/도어훅 문옷걸이 행거 바지걸이, 혼합 색상, 1개
# 디비플러스 키펙스 컬러 폭조절 오버 도어훅, 블랙, 1개
# 리빙스토리 1+1 문에 거는 문 옷걸이 음자리 도어후크 방문 행거, 음자리도어후크-로즈골드, 2개
# 나이스후크 도어행거 2개 세트 (문행거), 블랙+화이트
# 리빙파이 도어훅 옷걸이 행거 7구, 블랙, 1개
# 선우랜드 우드볼 도어훅 10구, 실버, 1개
# 웰렉스 도어행거 MH1060 신형 본사직발송 미니건조대 도어옷걸이 도어훅, 고동색, 1개
# 엔비 엔틱 7구 도어훅 옷걸이, 도어훅 1+1, 1+1
# 코시나 무타공 문걸이 후크선반 1단, 화이트, 1개
# 코시나 무타공 올스텐 문걸이행거, 혼합 색상, 1개
# [아트박스 POOM/이케아] ENUDDEN 도어 행거, 본품, 수량
# 비스비바 우드 폴 다용도걸이 3구, 혼합 색상, 1개
# 숲속애 웨이브 도어후크 5구, 블랙, 1개
# 펀타스틱 다용도 문틀걸이, 화이트, 1개
# 선우랜드 우드볼 도어훅 4구, 화이트, 1개
# 네이쳐리빙 어반모카 와이어 도어훅 옷걸이 6구, 단일 색상, 1개
# 까사마루 블랑 접이식 문걸이 건조대, 1개
# 선우랜드 우드볼 도어훅 6구, 실버, 1개
# 이케아 ENUDDEN 문걸이 행거 402.516.66, 화이트, 1개
# 선우랜드 우드볼 도어훅 10구, 화이트, 1개
# 코멧 홈 우드볼 도어행거, 6구, 혼합색상
# 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 코시나 무타공 문걸이 후크선반 2단, 화이트, 1개
# 스파이더락 도어후크 8구, 화이트, 1개
# 선우랜드 우드볼 도어훅 6구, 화이트, 1개
# 코멧 홈 우드볼 도어행거, 10구, 혼합색상

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #E65100;background-color:#FFF3E0;padding:10px">
# <font size="4em" style="font-weight:bold;color:#BF360C;">기본 데이터 분석</font><br>
# <font size="3em" style="color:#BF360C;">카테고리 종류를 알려주세요</font>
#
# <code>
# SELECT DISTINCT CATEGORY FROM teddyproducts
# </code>
#
# </div>

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #E65100;background-color:#FFF3E0;padding:10px">
# <font size="4em" style="font-weight:bold;color:#BF360C;">기본 데이터 분석</font><br>
# <font size="3em" style="color:#BF360C;">카테고리별 상품 갯수를 알려주세요</font>
#
# <code>
# SELECT CATEGORY, COUNT(*) FROM teddyproducts GROUP BY CATEGORY
# </code>
#
# </div>
