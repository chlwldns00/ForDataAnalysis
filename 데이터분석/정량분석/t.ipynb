# %%
import pandas as pd
df=pd.read_csv('북마크 기능 사용자 만족도 조사(응답) - 설문지 응답 시트1.csv')
df.head()
# Out:
#                     타임스탬프 Q1-1. 귀하의 연령대를 선택해주세요. Q1-2. 귀하의 직업을 선택해주세요.  \
# 0  2024. 6. 27 오후 5:09:31                    20대                 취업준비생
# 1  2024. 6. 27 오후 5:15:12                    20대                 취업준비생
# 2  2024. 6. 27 오후 5:15:31                    20대                 취업준비생
# 3  2024. 6. 27 오후 5:20:53                    20대                 취업준비생
# 4  2024. 6. 27 오후 5:28:04                    30대                 취업준비생
#
#   Q1-3. 웹/모바일 환경에서 북마크 기능을 사용하십니까?  Q2-1.북마크 기능을 사용하는 빈도는 어떻습니까?  \
# 0                                예                           5.0
# 1                                예                           5.0
# 2                                예                           4.0
# 3                                예                           3.0
# 4                                예                           5.0
#
#   Q2-2. 북마크 기능을 주로 사용하는 디바이스는 무엇입니까?  \
# 0                           데스크탑(PC)
# 1                           데스크탑(PC)
# ...

# %%
filtered_df_task = df[df['Q2-4. 북마크 기능을 사용하는 목적은 무엇입니까? (복수 선택 가능)'].str.contains('업무 및 과제에 필요한 정보 수집', na=False)]
filtered_df_task
#filtered_df.shape
# Out:
#                       타임스탬프 Q1-1. 귀하의 연령대를 선택해주세요. Q1-2. 귀하의 직업을 선택해주세요.  \
# 0    2024. 6. 27 오후 5:09:31                    20대                 취업준비생
# 1    2024. 6. 27 오후 5:15:12                    20대                 취업준비생
# 2    2024. 6. 27 오후 5:15:31                    20대                 취업준비생
# 3    2024. 6. 27 오후 5:20:53                    20대                 취업준비생
# 4    2024. 6. 27 오후 5:28:04                    30대                 취업준비생
# 5    2024. 6. 27 오후 5:29:12                    20대                 취업준비생
# 6    2024. 6. 27 오후 5:29:54                    20대                 취업준비생
# 7    2024. 6. 27 오후 5:31:45                    30대                 취업준비생
# 8    2024. 6. 27 오후 5:37:39                    20대                   직장인
# 10   2024. 6. 27 오후 5:43:35                    20대         대학생 (대학원생 포함)
# 13   2024. 6. 27 오후 5:53:28                    30대                 취업준비생
# 15   2024. 6. 27 오후 5:54:49                    20대                   직장인
# ...
